# %% [markdown]
# <a href="https://colab.research.google.com/github/GydeokLee/dl23/blob/main/DL/DLW04B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌳 **Digital Literacy & English Education** (Week 04B - Group Activities):
#
# * Introduction and experiencing chatGPT
# * Greate an md(markup) file on Github

# %% [markdown]
# # 🌀 Activity [1]
#
# Quiz #1 for the reading 01: group quiz (open book)
#
# QR code below or [rec.ac.kr/gnu](https://rec.ac.kr/gnu)

# %%
#@markdown Install {pyqrcode} and enter link address
# !pip install pyqrcode

import pyqrcode
from pyqrcode import QRCode

#@markdown Enter the link, save it as a file, and display
s = input("Paste the link: ")

# Generate QR code
url = pyqrcode.create(s)

# Create and save the png file naming "myqr.png"
url.svg("myqrcode.svg", scale=10)

from IPython.display import SVG, display
def show_svg(file):
    display(SVG(file))

show_svg("myqrcode.svg")

# %% [markdown]
# ## 📌 Setting-ups

# %%
#@markdown 💠 Import libraries {Image, Audio, YouTubeVideo}
from IPython.display import Image, Audio, YouTubeVideo

# %%
#@markdown 🔄 Making functions: etts('text'), ktts('text')
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

def etts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = True)
  
  gtts_object.save("E-audio.mp3")
  return Audio("E-audio.mp3")

def ktts(text):
  text_to_say = text

  gtts_object = gTTS(text = text_to_say,
                     lang = "ko",
                    slow = False)
  
  gtts_object.save("K-audio.mp3")
  return Audio("K-audio.mp3")

# %% [markdown]
# # 🌀 Activity [1]
#
# ## - Experience chatGPT and discover what it can do for you.
# (⌚_Spare 15 minutes' testing chatGPT + discuss what you've experienced with this tool._)
#
# * [chatGPT link](https://chat.openai.com)

# %%
#@markdown Play instructions: Choose your group and run this code.

group_number = "5" #@param = [1, 2, 3, 4, 5, 6]
gn = int(group_number)
gns = ["Group one", "Group two", "Group three", "Group four", "Group five","Group six"]

gnind = gn - 1
gnum = gns[gnind]

txt1 = "I'm giving you this instruction on be half of Professor Miran Kim. She instructed me to explain what you're supposed to do together in this activity. First, please visit the ChatGPT online page. The link is provided above. To avoid leaving the current page, do not click the link directly; instead, right-click the link and choose to open it in a new tab. Once you're on the ChatGPT page, you will be prompted to log in. Log in using your group leader's account."
txt2 = "Use the main screen logged in with the group leader's account for discussion. If time allows and you all agree, you can also log in individually using your smartphone, iPad, laptop, or other devices to practice. However, please make sure to engage in the activity of asking questions and viewing the results together on the main screen."
txt3 = "When using chatGPT, type a question in English. Korean also works but I hope you practice in English for most of the given time. Questions can include English grammar, vocabulary, spelling, or pronunciation check. While using chatGPT, think about how the tool can be useful in learning or teaching English. I hope you enjoy it."

mytxt = "Welcome " + gnum + "!" + txt1 + txt2 + txt3
etts(mytxt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 🌀 Activity [2]
#
# ## - Experience chatGPT and discover what it can do for you. (_Spare 10 minutes for this activity_)
#
# 1. Visit [chat.openai.com](https://chat.openai.com)
# 2. Querying: Ask any questions and see what it does.
# (e.g., how to pronounce 'querying'?)

# %%
#@markdown Instruction for Activity #2: run this code to listen to the instruction.
txt = "Here's the instruction for the second activity: Share online tools that you think others might not be aware of, but are useful. Take the time to visit the websites directly and demonstrate how they work. When sharing is done, choose two applications or websites that are worth sharing with your classmates. Think about why those tools could be useful to your classmates as English majoring students. Okay, I look forward to learning new tools from you!"

etts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## - Plan how to create videos to introduce the tools you've selected. (Make 2 mins' introduction videos of the two apps/software)
#
# + Video 1: in Korean (group members' voice)
# + Video 2: in English (using gTTS voice)

# %%
# !pip install gTTS
from gtts import gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from IPython.display import Audio

# %%
def tts(text):
  gtts_object = gTTS(text,lang = "en", slow = True) 
  gtts_object.save("myaudio.mp3")
  return Audio("myaudio.mp3")

# %%
tts('BBC Learning English offers a variety of free online resources for people learning English, covering topics such as vocabulary, grammar, pronunciation, conversation, business English, and culture, with materials including online audio, video, articles, and quizzes, allowing learners to improve their English language skills. It provides materials for learners of various levels from beginner to advanced, allowing learners to personalize their learning using various tools.')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text(좀만 기다려주세요 교수님 저희 유튜브에 업로드 중입니다.....)

# %% [markdown]
# * After discussing useful apps/tools, you'll be making two videos of introducing the apps **in English.** (Each video should be less than 2 minutes)

# %% [markdown]
# * 📌 Share the software names and weblinks [here](https://docs.google.com/spreadsheets/d/1g0BJwqMRLZh1JiCzqiGbp7Ao3LrgLrb8gLfEVmjf7_0/edit?usp=sharing). Be sure to check later if there is anything that overlaps with what you have chosen.
